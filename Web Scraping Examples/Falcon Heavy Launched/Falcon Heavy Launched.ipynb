# %%
import pandas as pd
import ssl 

ssl._create_default_https_context=ssl._create_unverified_context

scraper=pd.read_html("https://en.wikipedia.org/wiki/Falcon_Heavy")


for idx, table in enumerate(scraper):
    print("*********************************")
    print(idx)
    print(table)
# Out:
# *********************************
# 0
#                                            0  \
# 0                                        NaN
# 1            Falcon Heavy test flight launch
# 2                                   Function
# 3                               Manufacturer
# 4                          Country of origin
# 5                            Cost per launch
# 6                                       Size
# 7                                     Height
# 8                                   Diameter
# 9                                      Width
# 10                                      Mass
# 11                                    Stages
# 12                                  Capacity
# 13                Payload to low Earth orbit
# 14                       Orbital inclination
# 15                                      Mass
# 16  Payload to geosynchronous transfer orbit
# 17                       Orbital inclination
# 18                                      Mass
# ...

# %%
scraper[3]
# Out:
#                                            Flight No.  \
# 0                                                   1
# 1   In this demonstration flight, a Tesla Roadster...
# 2                                                   2
# 3   Heavy communications satellite purchased by th...
# 4                                                   3
# 5   The mission supported the U.S. Air Force Natio...
# 6                                                   –
# 7   Falcon Heavy was originally slated to launch t...
# 8                                                   –
# 9   First SpaceX launch of Phase 2 USAF contract, ...
# 10                                                  –
# 11  Satellite will weigh 9,200 kg (20,300 lb)at la...
# 12                                                  –
# 13  Second classified flight of Falcon Heavy, awar...
# 14                                                  –
# 15  First classified flight of Falcon Heavy. The c...
# ...
